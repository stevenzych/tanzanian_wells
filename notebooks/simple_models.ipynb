# %% [markdown]
# # Introduction

# %% [markdown]
# This notebook does basic modeling on the cleaned `.csv` from `cleaning.ipynb`. The goal here is to look at individual models and their parameters before moving on to ensemble methods.

# %%
import pandas as pd
pd.set_option("max_columns", None)
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
# import sklearn ... which parts?

# %% [markdown]
# # Importing Data

# %%
df = pd.read_csv("../data/data_cleaned.csv")

# %%
df.drop("Unnamed: 0", inplace=True, axis=1)

# %%
df.head()
# Out:
#       id  amount_tsh        funder  gps_height     installer  longitude  \
# 0  69572      6000.0         Roman        1390         Roman  34.938093
# 1   8776         0.0       Grumeti        1399       GRUMETI  34.698766
# 2  34310        25.0  Lottery Club         686  World vision  37.460664
# 3  67743         0.0        Unicef         263        UNICEF  38.486161
# 4  19728         0.0   Action In A           0       Artisan  31.130847
#
#     latitude              wpt_name                    basin  subvillage  \
# 0  -9.856322                  none               Lake Nyasa    Mnyusi B
# 1  -2.147466              Zahanati            Lake Victoria     Nyamara
# 2  -3.821329           Kwa Mahundi                  Pangani     Majengo
# 3 -11.155298  Zahanati Ya Nanyumbu  Ruvuma / Southern Coast  Mahakamani
# 4  -1.825359               Shuleni            Lake Victoria  Kyanyamisa
#
#     region  region_code  district_code        lga        ward  population  \
# ...

# %%
# Should I change the prediction classifiers to 0, 1, 2 for "func", "func n r", and "nonfunc"?

# %% [markdown]
# # Train-Test Split

# %%
X = df.drop("status_group", axis=1)
y = df['status_group']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
y_train
# Out:
# 32888                 functional
# 20429             non functional
# 51003             non functional
# 33626                 functional
# 5866                  functional
#                   ...
# 45891             non functional
# 52416    functional needs repair
# 42613             non functional
# 43567             non functional
# 2732              non functional
# Name: status_group, Length: 44271, dtype: object

# %% [markdown]
# # Logistic Model

# %%
logreg = LogisticRegression(fit_intercept=False, C=1e12, solver='liblinear')

# %%
# logreg.fit(X_train, y_train)

# %%
# Can't handle strings... Let's try just numbers
