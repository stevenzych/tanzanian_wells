# %%
import pandas as pd
import numpy as np
pd.set_option('max_columns', None)

# %%
df = pd.read_csv('../data/data_cleaned.csv')

# %%
df.funder.value_counts()
# Out:
# Government Of Tanzania    9602
# Danida                    3309
# Hesawa                    2337
# Rwssp                     1477
# Kkkt                      1358
#                           ...
# Frankfurt                    1
# Nmdc India                   1
# Abddwe                       1
# Getekwe                      1
# Kalebejo Parish              1
# Name: funder, Length: 1894, dtype: int64

# %% [markdown]
# # HOLIESYT LOOP OF HOLIES

# %%
for i in df.funder.value_counts().index[:5]:
    df[i.replace(" ", "_")] = (df.funder == i).astype(int)

# %%
df.head()
# Out:
#    Unnamed: 0     id  amount_tsh        funder  gps_height     installer  \
# 0           0  69572      6000.0         Roman        1390         Roman
# 1           1   8776         0.0       Grumeti        1399       GRUMETI
# 2           2  34310        25.0  Lottery Club         686  World vision
# 3           3  67743         0.0        Unicef         263        UNICEF
# 4           4  19728         0.0   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name                    basin  \
# 0  34.938093  -9.856322                  none               Lake Nyasa
# 1  34.698766  -2.147466              Zahanati            Lake Victoria
# 2  37.460664  -3.821329           Kwa Mahundi                  Pangani
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu  Ruvuma / Southern Coast
# 4  31.130847  -1.825359               Shuleni            Lake Victoria
#
#    subvillage   region  region_code  district_code        lga        ward  \
# ...
